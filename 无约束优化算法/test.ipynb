# %%
import numpy as np

# %%
A = np.random.randint(1,10,(3,2))
B = np.random.randint(1,10,(3,2))

# %%
x = np.random.randint(1,10,3)

# %%
np.dot(x,x)
# Out:
# 14

# %%
x
# Out:
# array([1, 2, 3])

# %%
np.outer(x,x)
# Out:
# array([[1, 2, 3],
#        [2, 4, 6],
#        [3, 6, 9]])

# %%
A[1]
# Out:
# array([7, 7])

# %%
A
# Out:
# array([[8, 5],
#        [7, 7],
#        [6, 8]])
